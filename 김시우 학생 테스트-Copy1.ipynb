# %%
import os
import pickle

import numpy as np
import torch

import matplotlib.pyplot as plt

from torch.utils.data import DataLoader, random_split
from torch.nn.functional import one_hot

from data_loaders.pulja_data_loader import PuljaDataLoader
from models._20220530_00 import UserModel
from models.utils import collate_fn

if torch.cuda.is_available():
    from torch.cuda import FloatTensor, LongTensor
    torch.set_default_tensor_type(torch.cuda.FloatTensor)
else:
    from torch import FloatTensor, LongTensor

# %%
ckpt_path = "ckpts"
if not os.path.isdir(ckpt_path):
    os.mkdir(ckpt_path)

batch_size = 256
num_epochs = 100
train_ratio = 0.9

seq_len = 100

dim_v = 20

dataset = PuljaDataLoader(seq_len)

if torch.cuda.is_available():
    device = "cuda"
else:
    device = "cpu"

model = UserModel(dataset.num_c, dataset.num_d, dim_v).to(device)

train_size = int(len(dataset) * train_ratio)
test_size = len(dataset) - train_size

train_dataset, test_dataset = random_split(
    dataset, [train_size, test_size]
)

if os.path.exists(os.path.join(dataset.dataset_dir, "indices.pkl")):
    with open(os.path.join(dataset.dataset_dir, "indices.pkl"), "rb") as f:
        indices = pickle.load(f)
    train_dataset.indices = indices[0]
    test_dataset.indices = indices[1]
else:
    with open(os.path.join(dataset.dataset_dir, "indices.pkl"), "wb") as f:
        pickle.dump((train_dataset.indices, test_dataset.indices), f)

# %%
model.load_state_dict(
    torch.load(
        os.path.join(
            os.path.join(
                ckpt_path, "_20220530_00"
            ),
            "model_fin.ckpt"
        ),
        map_location=device
    )
)
model.eval()
# Out:
# UserModel(
#   (D): Embedding(7, 1)
#   (gru): GRU(40, 20, batch_first=True)
#   (linear_1): Sequential(
#     (0): Linear(in_features=20, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=20, out_features=1, bias=True)
#     (4): Dropout(p=0.5, inplace=False)
#   )
#   (linear_2): Sequential(
#     (0): Linear(in_features=60, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=20, out_features=1, bias=True)
#     (4): Dropout(p=0.5, inplace=False)
#   )
# )

# %%
start_seq = 0
# end_seq = 112917
end_seq = 107788

# %%
df_u = dataset.df[dataset.df["userSeq"] == 457]
df_u = df_u[(df_u["seq"] >= start_seq) & (df_u["seq"] <= end_seq)]

# %%
df_u
# Out:
#            seq  cunitSeq  userSeq  question_id answer isCorrect  duration  \
# 9914      9966     42889      457         3378      ④         Y       126
# 9916      9968     42889      457         4009      ③         Y        87
# 9917      9969     42889      457         3383     ⑤③         Y        47
# 9918      9970     42889      457         3385     ⑤④         Y        60
# 9919      9971     42889      457         4027      ③         Y        63
# ...        ...       ...      ...          ...    ...       ...       ...
# 107693  107784    176225      457         4819    432         Y        33
# 107694  107785    176225      457         4806     30         Y        40
# 107695  107786    176225      457         5649     36         Y        27
# 107696  107787    176225      457         5650    200         Y        29
# 107697  107788    176225      457         4914      ⑤         Y        42
#
#                     regdate  difficulty_cd category1     category2  \
# 9914    2021-07-21 16:51:46            1.0  1 집합과 명제  01 집합의 뜻과 표현
# 9916    2021-07-21 16:53:14            1.0  1 집합과 명제  01 집합의 뜻과 표현
# 9917    2021-07-21 16:54:02            2.0  1 집합과 명제  01 집합의 뜻과 표현
# 9918    2021-07-21 16:55:02            2.0  1 집합과 명제  01 집합의 뜻과 표현
# 9919    2021-07-21 16:56:06            2.0  1 집합과 명제  01 집합의 뜻과 표현
# ...                     ...            ...       ...           ...
# 107693  2021-12-13 21:41:41            4.0   3 경우의 수  07 경우의 수와 순열
# 107694  2021-12-13 21:42:23            4.0   3 경우의 수  07 경우의 수와 순열
# 107695  2021-12-13 21:42:51            4.0   3 경우의 수         08 조합
# 107696  2021-12-13 21:43:21            4.0   3 경우의 수         08 조합
# 107697  2021-12-13 21:44:04            4.0   3 경우의 수         08 조합
#
#            category3                      category4  \
# 9914    01 집합의 뜻과 표현                      [1] 집합의 뜻
# 9916    01 집합의 뜻과 표현                      [1] 집합의 뜻
# 9917    01 집합의 뜻과 표현                      [1] 집합의 뜻
# 9918    01 집합의 뜻과 표현                      [1] 집합의 뜻
# 9919    01 집합의 뜻과 표현                      [1] 집합의 뜻
# ...              ...                            ...
# 107693         02 순열                 [9] 이웃하는 순열의 수
# 107694         02 순열           [13] 순열을 이용한 자연수의 개수
# 107695         01 조합                     [7] 직선의 개수
# 107696         01 조합                    [9] 삼각형의 개수
# 107697         01 조합  [12] 조합을 이용하여 조를 나누는 경우의 수(2)
#
#                                         category5
# 9914                              [유형 01 1] 집합의 뜻
# 9916                              [유형 01 1] 집합의 뜻
# 9917                              [유형 01 1] 집합의 뜻
# 9918                              [유형 01 1] 집합의 뜻
# 9919                              [유형 01 1] 집합의 뜻
# ...                                           ...
# 107693      [유형 12 3] 이웃하는 순열의 수-2가지 이상의 경우로 나뉠 때
# 107694                   [유형 16 2] 자연수의 개수-배수의 개수
# 107695   [유형 07 2] 직선의 개수-조건을 만족시키지 않는 것을 제외하는 경우
# 107696                   [유형 09 1] 다각형의 개수(1)-삼각형
# 107697  [유형 13 2] 분할한 후 분배하는 방법의 수-적어도의 조건이 있는 경우
#
# [4032 rows x 14 columns]

# %%
df_u.iloc[-50:]
# Out:
#            seq  cunitSeq  userSeq  question_id   answer isCorrect  duration  \
# 105352  105443    171407      457         4923      266         N       196
# 105353  105444    171407      457         4911      160         Y        37
# 105354  105445    171408      457         5647       82         Y        50
# 105355  105446    171408      457         5214        ③         Y       124
# 105356  105447    171408      457         4007        ⑥         N       131
# 105357  105448    171409      457         5213       90         Y        14
# 105358  105449    171409      457         4889        6         Y        74
# 105360  105451    171412      457         5212        ②         Y         7
# 105361  105452    171412      457         4915       15         N        57
# 105362  105453    171412      457         5645        ①         Y        40
# 105363  105454    171412      457         5646        4         N        74
# 105365  105456    171412      457         4899       20         N        67
# 105366  105457    171413      457         4916        ④         Y        34
# 105367  105458    171413      457         4902        ②         Y        27
# 105369  105460    171413      457         5669        ①         N       129
# 105370  105461    171411      457         4913      630         N        79
# 105371  105462    171411      457         4920      630         Y        78
# 105372  105463    171411      457         4895        ⑤         Y        63
# 105373  105464    171411      457         4914        ⑤         Y        36
# 105374  105465    171410      457         4004  잘 모르겠음.         N        20
# 105375  105466    171410      457         4891      448         N       132
# 107249  107340    176225      457         4767        ③         Y        47
# 107250  107341    176225      457         5588        ③         Y         6
# 107252  107343    176225      457         5152        ①         Y        40
# 107256  107347    176225      457         5223        ③         Y        47
# 107260  107351    176225      457         4823        2         Y        53
# 107263  107354    176225      457         5611        ②         Y        47
# 107266  107357    176225      457         5609       60         Y        33
# 107269  107360    176225      457         5202        ⑤         Y        68
# 107662  107753    176226      457         4779       59         Y        23
# 107666  107757    176226      457         4781       37         Y        42
# 107668  107759    176227      457         3904       59         Y        20
# 107669  107760    176227      457        13999       43         N        18
# 107673  107764    176224      457         4779       59         Y        12
# 107674  107765    176224      457         4780        ⑤         Y        38
# 107676  107767    176224      457         3903       23         Y        18
# 107677  107768    176224      457        13993       19         Y        27
# 107678  107769    176224      457         3904       59         Y        14
# 107684  107775    176225      457         5207        ②         N       166
# 107685  107776    176225      457         5638        9         Y        65
# 107686  107777    176225      457         5228     2880         Y        42
# 107687  107778    176225      457         5212        ②         Y         7
# 107689  107780    176225      457         5656        ③         Y        21
# 107691  107782    176225      457         4787      420         Y        40
# 107692  107783    176225      457         4816       95         Y        44
# 107693  107784    176225      457         4819      432         Y        33
# 107694  107785    176225      457         4806       30         Y        40
# 107695  107786    176225      457         5649       36         Y        27
# 107696  107787    176225      457         5650      200         Y        29
# 107697  107788    176225      457         4914        ⑤         Y        42
#
#                     regdate  difficulty_cd category1     category2 category3  \
# 105352  2021-12-09 18:50:55            5.0   3 경우의 수         08 조합     01 조합
# 105353  2021-12-09 18:51:33            4.0   3 경우의 수         08 조합     01 조합
# 105354  2021-12-09 18:52:39            3.0   3 경우의 수         08 조합     01 조합
# 105355  2021-12-09 18:54:44            3.0   3 경우의 수         08 조합     01 조합
# 105356  2021-12-09 18:56:56            5.0   3 경우의 수         08 조합     01 조합
# 105357  2021-12-09 18:57:15            3.0   3 경우의 수         08 조합     01 조합
# 105358  2021-12-09 18:58:30            4.0   3 경우의 수         08 조합     01 조합
# 105360  2021-12-09 19:22:10            3.0   3 경우의 수         08 조합     01 조합
# 105361  2021-12-09 19:23:07            4.0   3 경우의 수         08 조합     01 조합
# 105362  2021-12-09 19:23:49            4.0   3 경우의 수         08 조합     01 조합
# 105363  2021-12-09 19:25:04            4.0   3 경우의 수         08 조합     01 조합
# 105365  2021-12-09 19:26:12            5.0   3 경우의 수         08 조합     01 조합
# 105366  2021-12-09 19:26:59            3.0   3 경우의 수         08 조합     01 조합
# 105367  2021-12-09 19:27:27            4.0   3 경우의 수         08 조합     01 조합
# 105369  2021-12-09 19:29:37            5.0   3 경우의 수         08 조합     01 조합
# 105370  2021-12-09 19:31:08            3.0   3 경우의 수         08 조합     01 조합
# 105371  2021-12-09 19:32:27            4.0   3 경우의 수         08 조합     01 조합
# 105372  2021-12-09 19:33:31            3.0   3 경우의 수         08 조합     01 조합
# 105373  2021-12-09 19:34:08            4.0   3 경우의 수         08 조합     01 조합
# 105374  2021-12-09 19:50:54            5.0   3 경우의 수         08 조합     01 조합
# 105375  2021-12-09 19:53:07            3.0   3 경우의 수         08 조합     01 조합
# 107249  2021-12-13 17:18:49            3.0   3 경우의 수  07 경우의 수와 순열  01 경우의 수
# 107250  2021-12-13 17:18:55            3.0   3 경우의 수  07 경우의 수와 순열  01 경우의 수
# 107252  2021-12-13 17:19:37            3.0   3 경우의 수  07 경우의 수와 순열  01 경우의 수
# 107256  2021-12-13 17:20:25            3.0   3 경우의 수  07 경우의 수와 순열     02 순열
# 107260  2021-12-13 17:21:20            3.0   3 경우의 수  07 경우의 수와 순열     02 순열
# 107263  2021-12-13 17:22:07            3.0   3 경우의 수  07 경우의 수와 순열     02 순열
# 107266  2021-12-13 17:22:42            4.0   3 경우의 수  07 경우의 수와 순열     02 순열
# 107269  2021-12-13 17:23:51            3.0   3 경우의 수         08 조합     01 조합
# 107662  2021-12-13 21:27:36            3.0   3 경우의 수  07 경우의 수와 순열  01 경우의 수
# 107666  2021-12-13 21:28:19            4.0   3 경우의 수  07 경우의 수와 순열  01 경우의 수
# 107668  2021-12-13 21:28:45            4.0   3 경우의 수  07 경우의 수와 순열  01 경우의 수
# 107669  2021-12-13 21:29:04            4.0   3 경우의 수  07 경우의 수와 순열  01 경우의 수
# 107673  2021-12-13 21:30:08            3.0   3 경우의 수  07 경우의 수와 순열  01 경우의 수
# 107674  2021-12-13 21:30:46            3.0   3 경우의 수  07 경우의 수와 순열  01 경우의 수
# 107676  2021-12-13 21:31:05            4.0   3 경우의 수  07 경우의 수와 순열  01 경우의 수
# 107677  2021-12-13 21:31:34            4.0   3 경우의 수  07 경우의 수와 순열  01 경우의 수
# 107678  2021-12-13 21:31:48            4.0   3 경우의 수  07 경우의 수와 순열  01 경우의 수
# 107684  2021-12-13 21:37:21            3.0   3 경우의 수         08 조합     01 조합
# 107685  2021-12-13 21:38:27            3.0   3 경우의 수         08 조합     01 조합
# 107686  2021-12-13 21:39:10            3.0   3 경우의 수         08 조합     01 조합
# 107687  2021-12-13 21:39:19            3.0   3 경우의 수         08 조합     01 조합
# 107689  2021-12-13 21:39:41            3.0   3 경우의 수         08 조합     01 조합
# 107691  2021-12-13 21:40:22            4.0   3 경우의 수  07 경우의 수와 순열  01 경우의 수
# 107692  2021-12-13 21:41:07            4.0   3 경우의 수  07 경우의 수와 순열  01 경우의 수
# 107693  2021-12-13 21:41:41            4.0   3 경우의 수  07 경우의 수와 순열     02 순열
# 107694  2021-12-13 21:42:23            4.0   3 경우의 수  07 경우의 수와 순열     02 순열
# 107695  2021-12-13 21:42:51            4.0   3 경우의 수         08 조합     01 조합
# 107696  2021-12-13 21:43:21            4.0   3 경우의 수         08 조합     01 조합
# 107697  2021-12-13 21:44:04            4.0   3 경우의 수         08 조합     01 조합
#
#                              category4  \
# 105352                     [9] 삼각형의 개수
# 105353                     [9] 삼각형의 개수
# 105354                    [10] 사각형의 개수
# 105355                    [10] 사각형의 개수
# 105356                    [10] 사각형의 개수
# 105357                    [10] 사각형의 개수
# 105358                    [10] 사각형의 개수
# 105360                     [13] 함수의 개수
# 105361                     [13] 함수의 개수
# 105362                     [13] 함수의 개수
# 105363                     [13] 함수의 개수
# 105365                     [13] 함수의 개수
# 105366                   [14] 대진표 작성하기
# 105367                   [14] 대진표 작성하기
# 105369                   [14] 대진표 작성하기
# 105370   [12] 조합을 이용하여 조를 나누는 경우의 수(2)
# 105371   [12] 조합을 이용하여 조를 나누는 경우의 수(2)
# 105372   [12] 조합을 이용하여 조를 나누는 경우의 수(2)
# 105373   [12] 조합을 이용하여 조를 나누는 경우의 수(2)
# 105374   [11] 조합을 이용하여 조를 나누는 경우의 수(1)
# 105375   [11] 조합을 이용하여 조를 나누는 경우의 수(1)
# 107249             [2] 방정식과 부등식의 해의 개수
# 107250                       [3] 곱의 법칙
# 107252                      [4] 약수의 개수
# 107256        [11] 자리에 대한 조건이 있는 순열의 수
# 107260          [12] 적어도의 조건이 있는 순열의 수
# 107263           [14] 사전식 배열에 의한 경우의 수
# 107266            [13] 순열을 이용한 자연수의 개수
# 107269                 [2] nCr를 이용한 증명
# 107662             [6] 지불 방법과 지불 금액의 수
# 107666             [6] 지불 방법과 지불 금액의 수
# 107668             [6] 지불 방법과 지불 금액의 수
# 107669             [6] 지불 방법과 지불 금액의 수
# 107673             [6] 지불 방법과 지불 금액의 수
# 107674             [6] 지불 방법과 지불 금액의 수
# 107676             [6] 지불 방법과 지불 금액의 수
# 107677             [6] 지불 방법과 지불 금액의 수
# 107678             [6] 지불 방법과 지불 금액의 수
# 107684  [4] 특정한 것을 포함하거나 포함하지 않는 조합의 수
# 107685         [5] 적어도 ~의 조건이 있는 조합의 수
# 107686              [6] 뽑아서 나열하는 경우의 수
# 107687                     [13] 함수의 개수
# 107689                   [14] 대진표 작성하기
# 107691                  [8] 색칠하는 경우의 수
# 107692             [6] 지불 방법과 지불 금액의 수
# 107693                  [9] 이웃하는 순열의 수
# 107694            [13] 순열을 이용한 자연수의 개수
# 107695                      [7] 직선의 개수
# 107696                     [9] 삼각형의 개수
# 107697   [12] 조합을 이용하여 조를 나누는 경우의 수(2)
#
#                                                 category5
# 105352                           [유형 09 1] 다각형의 개수(1)-삼각형
# 105353              [유형 09 2] 다각형의 개수(1)-특정한 삼각형을 제외하는 경우
# 105354                           [유형 10 1] 다각형의 개수(2)-사각형
# 105355              [유형 10 2] 다각형의 개수(2)-특정한 사각형을 제외하는 경우
# 105356              [유형 10 2] 다각형의 개수(2)-특정한 사각형을 제외하는 경우
# 105357                                [유형 11 1] 평행사변형의 개수
# 105358              [유형 11 2] 평행사변형의 개수-평행사변형의 개수가 주어진 경우
# 105360                                   [유형 14 1] 함수의 개수
# 105361                                   [유형 14 1] 함수의 개수
# 105362                                   [유형 14 1] 함수의 개수
# 105363                                   [유형 14 1] 함수의 개수
# 105365                             [유형 14 2] 함수의 개수-일대일대응
# 105366                                 [유형 15 1] 대진표 작성하기
# 105367                                 [유형 15 1] 대진표 작성하기
# 105369                                 [유형 15 1] 대진표 작성하기
# 105370                         [유형 13 1] 분할한 후 분배하는 방법의 수
# 105371                         [유형 13 1] 분할한 후 분배하는 방법의 수
# 105372          [유형 13 2] 분할한 후 분배하는 방법의 수-적어도의 조건이 있는 경우
# 105373          [유형 13 2] 분할한 후 분배하는 방법의 수-적어도의 조건이 있는 경우
# 105374                               [유형 12 1] 분할하는 방법의 수
# 105375                [유형 12 2] 분할하는 방법의 수-적어도의 조건이 있는 경우
# 107249               [유형 02 1] 방정식과 부등식의 해의 개수-방정식의 해의 개수
# 107250                              [유형 03 2] 곱의 법칙-항의 개수
# 107252                                   [유형 04 1] 약수의 개수
# 107256                      [유형 14 1] 자리에 대한 조건이 있는 순열의 수
# 107260          [유형 15 2] 적어도의 조건이 있는 순열의 수-경우의 수가 주어졌을 때
# 107263         [유형 17 1] 사전식으로 배열하는 방법의 수-문자를 사전식으로 배열할 때
# 107266                           [유형 16 2] 자연수의 개수-배수의 개수
# 107269                              [유형 02 1] nCr를 이용한 증명
# 107662                       [유형 06 1] 지불 방법의 수와 지불 금액의 수
# 107666                       [유형 06 1] 지불 방법의 수와 지불 금액의 수
# 107668                       [유형 06 1] 지불 방법의 수와 지불 금액의 수
# 107669                       [유형 06 1] 지불 방법의 수와 지불 금액의 수
# 107673                       [유형 06 1] 지불 방법의 수와 지불 금액의 수
# 107674                       [유형 06 1] 지불 방법의 수와 지불 금액의 수
# 107676                       [유형 06 1] 지불 방법의 수와 지불 금액의 수
# 107677                       [유형 06 1] 지불 방법의 수와 지불 금액의 수
# 107678                       [유형 06 1] 지불 방법의 수와 지불 금액의 수
# 107684               [유형 04 1] 특정한 것을 포함하거나 포함하지 않는 조합의 수
# 107685        [유형 05 2] 적어도 ~의 조건이 있는 조합의 수-경우의 수가 주어졌을 때
# 107686                           [유형 06 1] 뽑아서 나열하는 경우의 수
# 107687                                   [유형 14 1] 함수의 개수
# 107689                                 [유형 15 1] 대진표 작성하기
# 107691  [유형 08 3] 색칠하는 방법의 수-같은 색 또는 다른 색을 칠하는 경우로 나누어...
# 107692                       [유형 06 1] 지불 방법의 수와 지불 금액의 수
# 107693              [유형 12 3] 이웃하는 순열의 수-2가지 이상의 경우로 나뉠 때
# 107694                           [유형 16 2] 자연수의 개수-배수의 개수
# 107695           [유형 07 2] 직선의 개수-조건을 만족시키지 않는 것을 제외하는 경우
# 107696                           [유형 09 1] 다각형의 개수(1)-삼각형
# 107697          [유형 13 2] 분할한 후 분배하는 방법의 수-적어도의 조건이 있는 경우

# %%
df_temp = df_u[(df_u["seq"] >= start_seq) & (df_u["seq"] <= 10034)]

c_seq_temp = np.array(
    [dataset.c2idx[c] for c in df_temp["category2"].values]
)
d_seq_temp = np.array(
    [dataset.d2idx[d] for d in df_temp["difficulty_cd"].values]
)

T_seq_temp = df_temp["duration"].values
T_hat_seq_temp = np.array(
    [dataset.difficulty2duration[dataset.d_list[d]] for d in d_seq_temp]
)
TR_seq_temp = T_seq_temp / T_hat_seq_temp

r_seq_temp = (df_temp["isCorrect"].values == "Y").astype(float)
r_seq_temp = dataset.get_response(r_seq_temp, TR_seq_temp)

# %%
np.mean(df_u[(df_u["seq"] >= start_seq) & (df_u["seq"] <= 10034)]["isCorrect"].values == "Y")
# Out:
# 0.9183673469387755

# %%
np.mean(r_seq_temp)
# Out:
# 0.8367346938775511

# %%
df_temp = df_u[(df_u["seq"] >= 107340) & (df_u["seq"] <= end_seq)]

c_seq_temp = np.array(
    [dataset.c2idx[c] for c in df_temp["category2"].values]
)
d_seq_temp = np.array(
    [dataset.d2idx[d] for d in df_temp["difficulty_cd"].values]
)

T_seq_temp = df_temp["duration"].values
T_hat_seq_temp = np.array(
    [dataset.difficulty2duration[dataset.d_list[d]] for d in d_seq_temp]
)
TR_seq_temp = T_seq_temp / T_hat_seq_temp

r_seq_temp = (df_temp["isCorrect"].values == "Y").astype(float)
r_seq_temp = dataset.get_response(r_seq_temp, TR_seq_temp)

# %%
np.mean(df_u[(df_u["seq"] >= 107340) & (df_u["seq"] <= end_seq)]["isCorrect"].values == "Y")
# Out:
# 0.9310344827586207

# %%
np.mean(r_seq_temp)
# Out:
# 0.9310344827586207

# %%
c_seq = np.array(
    [dataset.c2idx[c] for c in df_u["category2"].values]
)
d_seq = np.array(
    [dataset.d2idx[d] for d in df_u["difficulty_cd"].values]
)

T_seq = df_u["duration"].values
T_hat_seq = np.array(
    [dataset.difficulty2duration[dataset.d_list[d]] for d in d_seq]
)
TR_seq = T_seq / T_hat_seq

r_seq = (df_u["isCorrect"].values == "Y").astype(float)
r_seq = dataset.get_response(r_seq, TR_seq)

# %%
c_seq, d_seq, r_seq
# Out:
# (array([ 2,  2,  2, ..., 28, 28, 28]),
#  array([0, 0, 1, ..., 3, 3, 3]),
#  array([0., 1., 1., ..., 1., 1., 1.]))

# %%
alpha_seq, h_seq, C_seq = model(
    LongTensor([c_seq]),
    LongTensor([d_seq]),
    FloatTensor([r_seq]),
)

# %%
alpha_seq.shape
# Out:
# torch.Size([4032])

# %%
alpha_seq, h_seq, C_seq = model(
    LongTensor([c_seq]),
    LongTensor([d_seq]),
    FloatTensor([r_seq]),
)
alpha_seq = alpha_seq.squeeze()

sigmoid_alpha_seq = torch.sigmoid(alpha_seq).detach().cpu().numpy()

# sigmoid_alpha_beta_seq = torch.sigmoid(alpha_seq + beta_seq).detach().cpu().numpy()[0]

# sigmoid_alpha_beta_gamma_seq = torch.sigmoid(alpha_seq + beta_seq - gamma_seq).detach().cpu().numpy()[0]

CQ_seq = torch.sigmoid(C_seq.squeeze() + alpha_seq.unsqueeze(-1)).detach().cpu().numpy()
C_seq = C_seq.squeeze().detach().cpu().numpy()

# alpha_seq = alpha_seq.detach().cpu().numpy()

# %%
plt.figure(figsize=[15, 5], facecolor="white")
plt.plot(r_seq[:100], label="r_seq")
plt.plot((d_seq[:100] + 1) / 10, label="d_seq")
plt.plot(sigmoid_alpha_seq[:100], label="sigmoid_alpha_seq")
plt.grid()
plt.ylim(0, 1)
plt.legend()
plt.show()

# %%
plt.figure(figsize=[15, 5], facecolor="white")
plt.plot(r_seq[-100:], label="r_seq")
plt.plot((d_seq[-100:] + 1) / 10, label="d_seq")
plt.plot(sigmoid_alpha_seq[-100:], label="sigmoid_alpha_seq")
plt.grid()
plt.ylim(0, 1)
plt.legend()
plt.show()

# %%
plt.figure(figsize=[15, 5], facecolor="white")
# plt.plot(r_seq[::10], label="r_seq")
plt.plot((d_seq[::10] + 1) / 10, label="d_seq")
plt.plot(sigmoid_alpha_seq[::10], label="sigmoid_alpha_seq")
plt.grid()
plt.ylim(0, 1)
plt.legend()
plt.show()

# %%
CQ_seq.shape, r_seq.shape
# Out:
# ((4032, 37), (4032,))

# %%
plt.figure(figsize=[20, 7], facecolor="white")
temp = np.concatenate([CQ_seq.T, [r_seq]], axis=0)
plt.pcolormesh(temp)
plt.colorbar()
plt.show()

# plt.figure(figsize=[15, 0.5], facecolor="white")
# plt.pcolormesh(r_seq)
# plt.show()

# %%
true_indices = \
    (dataset.c_list == "01 집합의 뜻과 표현") | \
    (dataset.c_list == "02 집합의 연산") | \
    (dataset.c_list == "03 명제") | \
    (dataset.c_list == "04 함수") | \
    (dataset.c_list == "05 유리함수") | \
    (dataset.c_list == "06 무리함수") | \
    (dataset.c_list == "07 경우의 수와 순열") | \
    (dataset.c_list == "08 조합")

# %%
true_indices
# Out:
# array([False, False,  True, False, False,  True, False,  True, False,
#        False, False, False, False, False,  True, False, False,  True,
#        False,  True, False, False,  True, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False])

# %%
CQ_seq[0][true_indices], CQ_seq[48][true_indices], CQ_seq[-1][true_indices], c_seq, d_seq
# Out:
# (array([0.3507404 , 0.41372472, 0.41372472, 0.41372472, 0.41372472,
#         0.41372472, 0.41372472, 0.41372472], dtype=float32),
#  array([0.55774283, 0.5314302 , 0.5314302 , 0.5314302 , 0.5314302 ,
#         0.5314302 , 0.5314302 , 0.5314302 ], dtype=float32),
#  array([0.72766376, 0.72998947, 0.7273265 , 0.6767312 , 0.7283773 ,
#         0.669014  , 0.7283687 , 0.7282553 ], dtype=float32),
#  array([ 2,  2,  2, ..., 28, 28, 28]),
#  array([0, 0, 1, ..., 3, 3, 3]))

# %%
dataset.c_list[true_indices]
# Out:
# array(['01 집합의 뜻과 표현', '02 집합의 연산', '03 명제', '04 함수', '05 유리함수',
#        '06 무리함수', '07 경우의 수와 순열', '08 조합'], dtype=object)

# %%
sigmoid_alpha_seq[0], sigmoid_alpha_seq[48], sigmoid_alpha_seq[-1], c_seq, d_seq
# Out:
# (0.41372472,
#  0.5314302,
#  0.68091416,
#  array([ 2,  2,  2, ..., 28, 28, 28]),
#  array([0, 0, 1, ..., 3, 3, 3]))
