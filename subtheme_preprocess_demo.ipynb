# %%
import numpy as np
import pandas as pd

# %%
tb_problems_path = "tables/tb_problems.csv"

tb_problems = pd.read_csv(tb_problems_path).dropna()

# %%
tb_problems
# Out:
#        question_id  difficulty_cd category1   category2     category3  \
# 0                3            1.0     1 다항식  01 다항식의 연산    01 다항식의 연산
# 2               12            2.0     1 다항식  01 다항식의 연산    01 다항식의 연산
# 3               14            3.0     1 다항식  01 다항식의 연산    01 다항식의 연산
# 8               29            3.0     1 다항식  01 다항식의 연산  02 다항식의 곱셈공식
# 11              36            3.0     1 다항식  01 다항식의 연산  02 다항식의 곱셈공식
# ...            ...            ...       ...         ...           ...
# 32786        38312            5.0      3 적분  09 정적분의 활용     02 속도와 거리
# 32787        38313            4.0      3 적분  09 정적분의 활용     02 속도와 거리
# 32788        38314            4.0      3 적분  09 정적분의 활용     02 속도와 거리
# 32789        38315            3.0      3 적분  09 정적분의 활용     02 속도와 거리
# 32790        38316            3.0      3 적분  09 정적분의 활용     02 속도와 거리
#
#                    category4                            category5
# ...

# %%
tb_problems[tb_problems["category1"] == '1 삼각비']
# Out:
#        question_id  difficulty_cd category1 category2 category3  \
# 17714        18373            5.0     1 삼각비    01 삼각비       소단원
# 17715        18374            5.0     1 삼각비    01 삼각비       소단원
# 17720        18379            3.0     1 삼각비    01 삼각비       소단원
# 17721        18380            3.0     1 삼각비    01 삼각비       소단원
#
#                                       category4  \
# 17714        [10] 특수한 각의 삼각비의 값을 이용하여 변의 길이 구하기
# 17715        [10] 특수한 각의 삼각비의 값을 이용하여 변의 길이 구하기
# 17720  [2] 한 변의 길이와 삼각비의 값을 알 때, 삼각형의 변의 길이 구하기
# 17721  [2] 한 변의 길이와 삼각비의 값을 알 때, 삼각형의 변의 길이 구하기
#
#                                             category5
# 17714         [유형 10 1] 특수한 각의 삼각비의 값을 이용하여 변의 길이 구하기
# 17715         [유형 10 1] 특수한 각의 삼각비의 값을 이용하여 변의 길이 구하기
# 17720  [유형 02 1] 한 변의 길이와 삼각비의 값을 알 때, 삼각형의 변의 길이 구하기
# 17721  [유형 02 1] 한 변의 길이와 삼각비의 값을 알 때, 삼각형의 변의 길이 구하기

# %%
tb_problems[tb_problems["category1"] == '1 실수와 그 연산']
# Out:
#        question_id  difficulty_cd   category1   category2 category3  \
# 17734        18393            3.0  1 실수와 그 연산  01 제곱근과 실수       소단원
# 17735        18394            3.0  1 실수와 그 연산  01 제곱근과 실수       소단원
# 17738        18397            3.0  1 실수와 그 연산  01 제곱근과 실수       소단원
# 17739        18398            3.0  1 실수와 그 연산  01 제곱근과 실수       소단원
#
#                                  category4  \
# 17734  [10] √A/x가 자연수가 되도록 하는 자연수 x의 값 구하기
# 17735  [10] √A/x가 자연수가 되도록 하는 자연수 x의 값 구하기
# 17738                  [14] 제곱근의 성질과 대소 관계
# 17739                  [14] 제곱근의 성질과 대소 관계
#
#                                      category5
# 17734  [유형10 1] √A/x가 자연수가 되도록 하는 자연수 x의 값 구하기
# 17735  [유형10 1] √A/x가 자연수가 되도록 하는 자연수 x의 값 구하기
# 17738                  [유형14 1] 제곱근의 성질과 대소 관계
# 17739                  [유형14 1] 제곱근의 성질과 대소 관계

# %%
tb_problems[tb_problems["category1"] == '4 통계']
# Out:
#        question_id  difficulty_cd category1      category2 category3  \
# 17766        18425            3.0      4 통계  08 자료의 정리와 해석       소단원
# 17767        18426            3.0      4 통계  08 자료의 정리와 해석       소단원
#
#            category4           category5
# 17766  [4] 히스토그램의 이해  [유형04 1] 히스토그램의 이해
# 17767  [4] 히스토그램의 이해  [유형04 1] 히스토그램의 이해

# %%
tb_problems[tb_problems["category1"] == '3 통계']
# Out:
#        question_id  difficulty_cd category1    category2 category3  \
# 17722        18381            3.0      3 통계      06 상관관계       소단원
# 17723        18382            3.0      3 통계      06 상관관계       소단원
# 17724        18383            4.0      3 통계  05 대푯값과 산포도       소단원
# 17725        18384            4.0      3 통계  05 대푯값과 산포도       소단원
#
#              category4                       category5
# 17722  [4] 산점도의 이해 (2)  [유형 04 2] 산점도의 이해 (2)+상대도수 구하기
# 17723  [4] 산점도의 이해 (2)  [유형 04 2] 산점도의 이해 (2)+상대도수 구하기
# 17724     [7] 분산과 표준편차              [유형 07 1] 분산과 표준편차
# 17725     [7] 분산과 표준편차              [유형 07 1] 분산과 표준편차

# %%
tb_problems[["category3", "category4"]].groupby("category3")["category4"].apply(set).apply(list).apply(sorted).to_dict()
# Out:
# {'01 ∑의 뜻과 그 성질': ['[16] 등차수열이나 등비수열의 일반항을 이용하는 경우',
#   '[18] 수열의 응용-n각수',
#   '[1] 합의 기호 ∑',
#   '[2] ∑의 기본 성질',
#   '[3] ∑_k=1^n r^k의 꼴의 계산',
#   '[4] 자연수의 거듭제곱의 합',
#   '[5] ∑를 이용한 수열의 합',
#   '[6] ∑로 표현된 수열의 합과 일반항 사이의 관계',
#   '[7] ∑를 여러 개 포함한 식의 계산',
#   '[8] 제k항이 n에 대한 식일 때의 수열의 합'],
#  '01 거듭제곱과 거듭제곱근': ['[1] 거듭제곱근', '[2] 거듭제곱근의 계산', '[3] 거듭제곱근의 대소 비교'],
#  '01 경우의 수': ['[0] 사건과 경우의 수',
#   '[1] 합의 법칙',
#   '[2] 방정식과 부등식의 해의 개수',
#   '[3] 곱의 법칙',
#   '[4] 약수의 개수',
#   '[5] 수형도를 이용하는 경우의 수',
#   '[6] 지불 방법과 지불 금액의 수',
#   '[7] 도로망에서의 경우의 수',
#   '[8] 색칠하는 경우의 수'],
#  '01 넓이': ['[11] 넓이의 활용-넓이가 최소일 때',
#   '[12] 역함수의 그래프와 넓이',
#   '[13] 넓이의 활용-그 이외의 활용',
#   '[1] 곡선과 x축 사이의 넓이',
#   '[2] 곡선과 직선 사이의 넓이',
#   '[3] 두 곡선 사이의 넓이',
#   '[4] 절댓값 기호를 포함한 그래프의 넓이',
#   '[5] 곡선과 접선으로 둘러싸인 도형의 넓이',
#   '[6] 두 도형의 넓이가 같을 때',
#   '[7] 넓이의 활용-넓이를 이등분할 때'],
#  '01 다항식의 연산': ['[1] 다항식의 덧셈과 뺄셈', '[2] 다항식의 전개식에서 계수 구하기'],
#  '01 두 점 사이의 거리': ['[1] 두 점 사이의 거리',
#   '[2] 같은 거리에 있는 점의 좌표',
# ...

# %%
np.unique(tb_problems["category1"].values)
# Out:
# array(['1 다항식', '1 삼각비', '1 삼각형의 성질', '1 실수와 그 연산', '1 지수함수와 로그함수',
#        '1 집합과 명제', '1 함수의 극한과 연속', '2 미분', '2 방정식과 부등식', '2 삼각함수',
#        '2 원의 성질', '2 평면도형', '2 함수', '3 경우의 수', '3 도형의 닮음과 피타고라스 정리',
#        '3 도형의 방정식', '3 수열', '3 이차방정식', '3 적분', '3 통계', '4 이차함수', '4 일차함수',
#        '4 통계', '4 확률'], dtype=object)

# %%
np.unique(tb_problems["category1"].values).shape
# Out:
# (24,)

# %%
np.unique(tb_problems["category2"].values)
# Out:
# array(['01 다항식의 연산', '01 삼각비', '01 제곱근과 실수', '01 지수', '01 집합의 뜻과 표현',
#        '01 함수의 극한', '02 로그', '02 삼각형의 외심과 내심', '02 집합의 연산', '02 함수의 연속',
#        '02 항등식과 나머지정리', '03 명제', '03 미분계수와 도함수', '03 원과 직선', '03 인수분해',
#        '03 지수함수', '04 도함수의 활용(1)', '04 로그함수', '04 복소수', '04 원주각', '04 함수',
#        '05 대푯값과 산포도', '05 도함수의 활용(2)', '05 도형의 닮음', '05 삼각함수',
#        '05 원과 부채꼴', '05 유리함수', '05 이차방정식', '05 이차방정식의 풀이',
#        '06 도함수의 활용(3)', '06 무리함수', '06 삼각함수의 그래프', '06 상관관계',
#        '06 이차방정식과 이차함수', '06 이차방정식의 활용', '07 경우의 수와 순열', '07 부정적분',
#        '07 삼각함수의 활용', '07 삼각형의 무게중심', '07 여러 가지 방정식', '07 이차함수와 그 그래프',
#        '08 등차수열과 등비수열', '08 연립일차부등식', '08 이차함수 y=ax²+bx+c의 그래프',
#        '08 일차함수와 그 그래프', '08 자료의 정리와 해석', '08 정적분', '08 조합',
#        '08 피타고라스 정리', '09 경우의 수', '09 수열의 합', '09 이차부등식과 연립이차부등식',
#        '09 일차함수와 일차방정식의 관계', '09 정적분의 활용', '10 수학적 귀납법', '10 평면좌표',
#        '10 확률', '11 직선의 방정식', '12 원의 방정식', '13 도형의 이동'], dtype=object)

# %%
np.unique(tb_problems["category3"].values)
# Out:
# array(['01 ∑의 뜻과 그 성질', '01 거듭제곱과 거듭제곱근', '01 경우의 수', '01 넓이',
#        '01 다항식의 연산', '01 두 점 사이의 거리', '01 등차수열', '01 로그의 뜻과 성질',
#        '01 로그함수의 뜻과 그래프', '01 명제와 조건', '01 무리식', '01 미분계수',
#        '01 방정식과 부등식에의 활용', '01 복소수의 성질과 연산', '01 부정적분', '01 사인법칙',
#        '01 삼각함수의 그래프', '01 삼차방정식과 사차방정식', '01 수열의 귀납적 정의', '01 연립일차부등식',
#        '01 원의 방정식', '01 유리식', '01 이차방정식', '01 이차방정식과 이차함수의 관계',
#        '01 이차부등식', '01 인수분해', '01 일반각과 호도법', '01 접선의 방정식', '01 정적분',
#        '01 조합', '01 지수함수의 뜻과 그래프', '01 직선의 방정식', '01 집합의 뜻과 표현',
#        '01 집합의 연산', '01 평행이동', '01 함수', '01 함수의 극한', '01 함수의 연속',
#        '01 함수의 증가와 감소', '01 항등식', '02 i의 거듭제곱, 음수의 제곱근', '02 나머지정리와 인수정리',
#        '02 다항식의 곱셈공식', '02 대칭이동', '02 도함수', '02 두 직선의 위치 관계',
#        '02 등차수열의 합', '02 로그함수의 최대 · 최소', '02 명제의 역, 대우', '02 무리함수',
#        '02 부분집합', '02 부정적분의 계산', '02 삼각함수가 포함된 방정식과 부등식', '02 삼각함수의 뜻',
#        '02 상용로그', '02 선분의 내분점과 외분점', '02 속도와 가속도', '02 속도와 거리',
# ...

# %%
np.unique(
    tb_problems\
    [tb_problems["category1"] == "2 방정식과 부등식"]\
    [tb_problems["category2"] == "07 여러 가지 방정식"]\
    ["category3"].values
)
# Out:
# <ipython-input-25-ff1a2a7d8b0f>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tb_problems\
# array(['01 삼차방정식과 사차방정식', '02 연립이차방정식', '03 부정방정식'], dtype=object)

# %%
np.unique(
    tb_problems\
    [tb_problems["category1"] == "2 방정식과 부등식"]\
    [tb_problems["category2"] == "06 이차방정식과 이차함수"]\
    ["category4"].values
)
# Out:
# <ipython-input-23-33bdcca314b0>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tb_problems\
# array(['[0] 이차함수의 그래프의 이해', '[10] 완전제곱식을 이용한 이차식의 최대 · 최소',
#        '[11] 조건이 주어진 이차식의 최대 · 최소', '[12] 이차함수의 최대 · 최소의 활용',
#        '[1] 이차함수의 그래프와 x축의 교점', '[2] 이차함수의 그래프와 x축의 위치 관계',
#        '[3] 이차함수의 그래프와 직선의 위치 관계', '[4] 이차함수의 그래프에 접하는 직선의 방정식',
#        '[5] 이차함수의 그래프와 직선의 교점', '[6] 이차함수의 최대 · 최소',
#        '[7] 최댓값 또는 최솟값이 주어질 때 미지수의 값 구하기', '[8] 제한된 범위에서의 이차함수의 최대 · 최소',
#        '[9] 공통부분이 있는 함수의 최대 · 최소'], dtype=object)

# %%
subtheme_dict = {
    "1 다항식": {
        "01 다항식의 연산": {
            "[1] 다항식의 덧셈과 뺄셈": ["다항식의 덧셈과 뺄셈"],
            "[2] 다항식의 전개식에서 계수 구하기": ["다항식의 덧셈과 뺄셈", "다항식의 곱셈"],
            "[3] 곱셈 공식을 이용한 다항식의 전개": ["다항식의 곱셈", "곱셈 공식"],
            "[4] 공통부분이 있는 다항식의 전개": ["다항식의 곱셈", "곱셈 공식"],
            "[5] 곱셈 공식의 변형-문자가 2개": ["다항식의 곱셈", "곱셈 공식", "곱셈 공식의 변형"],
            "[6] 곱셈 공식의 변형 - x±1/x의 꼴": ["다항식의 곱셈", "곱셈 공식", "곱셈 공식의 변형"],
            "[7] 곱셈 공식의 변형-문자가 3개": ["다항식의 곱셈", "곱셈 공식", "곱셈 공식의 변형"],
            "[8] 곱셈 공식을 이용한 수의 계산": ["다항식의 곱셈", "곱셈 공식"],
            "[9] 다항식의 나눗셈-몫과 나머지": ["다항식의 곱셈", "다항식의 나눗셈"],
            "[10] 다항식의 나눗셈-A=BQ+R": ["다항식의 곱셈", "다항식의 나눗셈"],
            "[11] 몫과 나머지의 변형": ["다항식의 곱셈", "다항식의 나눗셈"],
            "[12] 조립제법": ["다항식의 곱셈", "다항식의 나눗셈"],
            "[13] 특수한 식의 변형": ["다항식의 곱셈", "곱셈 공식", "곱셈 공식의 변형"],
            "[14] 곱셈 공식의 도형에의 활용": ["다항식의 곱셈", "곱셈 공식", "곱셈 공식의 변형"],
        },
        "02 항등식과 나머지정리": {
            "[1] 항등식에서 미정계수 구하기-계수비교법": ["다항식의 곱셈", "항등식"],
            "[2] 항등식에서 미정계수 구하기-수치대입법": ["항등식"],
            "[3] ~의 값에 관계없이 항상 성립하는 등식": ["항등식"],
            "[4] 조건식을 만족시키는 항등식": ["항등식"],
            "[5] 항등식에서 계수의 합 구하기": ["항등식"],
            "[6] 다항식의 나눗셈과 항등식": ["항등식"],
            "[7] 나머지정리-일차식으로 나누는 경우": ["나머지정리와 인수정리"],
            "[8] 나머지정리-이차식으로 나누는 경우": ["나머지정리와 인수정리"],
            "[9] 나머지정리-삼차식으로 나누는 경우": ["나머지정리와 인수정리"],
            "[10] f(ax+b)를 x-α로 나누는 경우": ["나머지정리와 인수정리"],
            "[11] 몫을 x-α로 나누는 경우": ["나머지정리와 인수정리"],
            "[12] 인수정리-일차식으로 나누는 경우": ["나머지정리와 인수정리"],
            "[13] 인수정리-이차식으로 나누는 경우": ["나머지정리와 인수정리"],
            "[14] 수의 나눗셈에서 나머지정리의 활용": ["나머지정리와 인수정리"],
            "[15] 조립제법과 항등식": ["다항식의 나눗셈과 항등식"],
            
            "[16] 다항식의 전개식에서 계수 구하기+나머지정리-일차식으로 나누는 경우": ["다항식의 덧셈과 뺄셈", "다항식의 곱셈", "나머지정리와 인수정리"],
            "[17] f(ax+b)를 x-α로 나누는 경우+나머지정리-일차식으로 나누는 경우": ["나머지정리와 인수정리", "나머지정리와 인수정리"],
        },
        "03 인수분해": {
            "[1] 인수분해 공식을 이용한 인수분해(1)": ["인수분해"],
            "[2] 인수분해 공식을 이용한 인수분해(2)": ["인수분해"],
            "[3] 공통부분이 있는 다항식의 인수분해": ["다항식의 곱셈", "복잡한 식의 인수분해"],
            "[4] x^4+ax^2+b의 꼴의 다항식의 인수분해": ["복잡한 식의 인수분해"],
            "[5] 여러 개의 문자가 포함된 다항식의 인수분해": ["다항식의 곱셈", "복잡한 식의 인수분해"],
            "[6] 인수정리를 이용한 다항식의 인수분해": ["나머지정리와 인수정리", "복잡한 식의 인수분해"],
            "[7] 순환하는 꼴의 다항식의 인수분해": ["다항식의 곱셈", "복잡한 식의 인수분해"],
            "[8] 계수가 대칭인 사차식의 인수분해": ["곱셈 공식의 변형", "복잡한 식의 인수분해"],
            "[9] 인수분해를 이용한 식의 값 구하기": ["곱셈 공식의 변형", "복잡한 식의 인수분해"],
            "[10] 인수분해를 이용한 수의 계산": ["복잡한 식의 인수분해"],
            "[11] 조건이 주어진 다항식의 인수분해": ["복잡한 식의 인수분해"],
            "[12] 인수분해를 이용한 삼각형 모양의 판단": ["복잡한 식의 인수분해"],
            
            "[13] 인수분해의 도형에의 활용",
            "[14] 인수분해에서의 항등식에서 미정계수 구하기-수치대입법",
        },
    },
    "2 방정식과 부등식": {
        "04 복소수": {
            "[1] 복소수의 뜻과 분류": ["복소수"],
            "[2] 복소수의 사칙연산": ["복소수의 연산"],
            "[3] 복소수가 주어질 때의 식의 값": ["복소수의 연산"],
            "[4] 복소수가 실수 또는 순허수가 되는 조건": ["복소수의 연산"],
            "[5] 복소수가 서로 같을 조건": ["복소수의 연산"],
            "[6] 켤레복소수의 성질": ["복소수의 연산"],
            "[7] 등식을 만족시키는 복소수 구하기": ["복소수의 연산"],
            "[8] i의 거듭제곱": ["복소수의 연산", "i의 거듭제곱", "음수의 제곱근"],
            "[9] 복소수의 거듭제곱": ["복소수의 연산", "i의 거듭제곱", "음수의 제곱근"],
            "[10] 음수의 제곱근의 계산": ["복소수의 연산", "i의 거듭제곱", "음수의 제곱근"],
            "[11] 음수의 제곱근의 성질": ["복소수의 연산", "i의 거듭제곱", "음수의 제곱근"],
            "[12] 켤레복소수의 성질의 활용": ["복소수의 연산"],
            "[13] 켤레복소수의 성질을 이용한 식의 계산": ["복소수의 연산"],
        },
        "05 이차방정식": {
            "[1] 이차방정식의 풀이": ["이차방정식"],
            "[2] 한 근이 주어진 이차방정식": ["이차방정식"],
            "[3] 절댓값 기호를 포함한 이차방정식": ["이차방정식"],
            "[4] 이차방정식의 활용": ["이차방정식"],
            "[5] 이차방정식의 근의 판별": ["이차방정식의 판별식"],
            "[6] 계수가 문자인 이차방정식의 근의 판별": ["이차방정식의 판별식"],
            "[7] 이차식이 완전제곱식이 될 조건": ["항등식", "이차방정식의 판별식"],
            "[8] 근과 계수의 관계를 이용하여 식의 값 구하기(1)": ["곱셈 공식의 변형", "이차방정식의 근과 계수의 관계"],
            "[9] 근과 계수의 관계를 이용하여 식의 값 구하기(2)": ["곱셈 공식의 변형", "이차방정식의 근과 계수의 관계"],
            "[10] 근과 계수의 관계를 이용하여 미정계수 구하기": ["이차방정식의 근과 계수의 관계"],
            "[11] 두 근 사이의 관계가 주어진 이차방정식": ["이차방정식의 근과 계수의 관계"],
            "[12] 두 이차방정식이 주어질 때 미정계수 구하기": ["이차방정식의 근과 계수의 관계"],
            "[13] 두 수를 근으로 하는 이차방정식": ["이차방정식", "이차방정식의 근과 계수의 관계"],
            "[14] 이차방정식의 켤레근의 성질": ["이차방정식의 근과 계수의 관계"],
            "[15] 이차식을 두 일차식의 곱으로 인수분해하기": ["이차방정식의 판별식"],
            "[16] 잘못 보고 푼 이차방정식": ["이차방정식", "이차방정식의 근과 계수의 관계"],
            "[17] 이차방정식 f(x)=0과 f(ax+b)=0의 관계": ["이차방정식", "이차방정식의 근과 계수의 관계"],
            
            "[18] 이차식의 인수분해",
        },
        "06 이차방정식과 이차함수": {
            "[0] 이차함수의 그래프의 이해",
            
            "[1] 이차함수의 그래프와 x축의 교점": ["이차방정식의 근과 계수의 관계", "이차방정식과 이차함수의 관계"],
            "[2] 이차함수의 그래프와 x축의 위치 관계": ["이차방정식의 판별식", "이차방정식과 이차함수의 관계"],
            "[3] 이차함수의 그래프와 직선의 위치 관계": ["이차방정식의 판별식", "이차방정식과 이차함수의 관계"],
            "[4] 이차함수의 그래프에 접하는 직선의 방정식": ["이차방정식의 판별식", "이차방정식과 이차함수의 관계"],
            "[5] 이차함수의 그래프와 직선의 교점": ["이차방정식의 근과 계수의 관계", "이차방정식과 이차함수의 관계"],
            "[6] 이차함수의 최대 · 최소": ["이차함수의 최대, 최소"],
            "[7] 최댓값 또는 최솟값이 주어질 때 미지수의 값 구하기": ["이차함수의 최대, 최소"],
            "[8] 제한된 범위에서의 이차함수의 최대 · 최소": ["이차함수의 최대, 최소"],
            "[9] 공통부분이 있는 함수의 최대 · 최소": ["이차함수의 최대, 최소"],
            "[10] 완전제곱식을 이용한 이차식의 최대 · 최소": ["이차함수의 최대, 최소"],
            "[11] 조건이 주어진 이차식의 최대 · 최소": ["이차함수의 최대, 최소"],
            "[12] 이차함수의 최대 · 최소의 활용": ["도형의 닮음", "이차함수의 최대, 최소"],
        },
        "07 여러 가지 방정식",
        "08 연립일차부등식",
        "09 이차부등식과 연립이차부등식",
    },
    "3 도형의 방정식": {
        
    },
    "1 집합과 명제" :{
        
    },
    "2 함수": {
        
    },
    "3 경우의 수": {
        
    },
    "1 지수함수와 로그함수": {
        
    },
    "2 삼각함수": {
        
    },
    "3 수열": {
        
    },
    "1 함수의 극한과 연속": {
        
    },
    "2 미분": {
        
    },
    "3 적분": {
        
    },
}
# Out:
#   File "<ipython-input-19-39298353ae0b>", line 53
#     "[13] 인수분해의 도형에의 활용",
#                         ^
# SyntaxError: invalid syntax
